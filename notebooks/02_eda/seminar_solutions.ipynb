# %% [markdown]
# # Week 2 - Seminar - Exploratory Data Analysis and Plotting

# %%
import duckdb
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# This prevents pandas from showing weird warnings
pd.options.mode.chained_assignment = None

db_path = "data.duckdb"
schema = "data.attendance"

conn = duckdb.connect()
conn.execute(f"ATTACH '{db_path}' AS data (READ_ONLY)")
conn.execute(f"USE {schema}");

# %% [markdown]
# ## Agenda
#
# Repeat 10 times:
# 1. I show you the task
# 2. You work on it for 3-5 minutes
# 3. I show you my solution
# 4. You compare my solution to yours and raise questions, we discuss for several minutes.

# %% [markdown]
# ## Data Preprocessing

# %%
df = conn.sql(
    """
        WITH attendance AS (
            SELECT
                report_period,
                school_code,
                student_class,
                subject_code,
                electronic_diary,
                FIRST(student_count_diary) student_count_diary,
                SUM(excused_lessons_illness) excused_lessons_illness,
                SUM(excused_lessons_other) excused_lessons_other,
                SUM(unexcused_lessons) unexcused_lessons
            FROM attendance
            WHERE division_code IS NULL
            GROUP BY all
        ),
            school AS (
            SELECT 
                school_code, 
                school_name, 
                municipality_name
            FROM school
            WHERE division_code IS NULL
        ),
            subject AS (
            SELECT
                electronic_diary,
                subject_code,
                subject_name_en,
            FROM subject
        )
        SELECT
            school.school_name,
            school.school_code,
            school.municipality_name,
            attendance.student_class,
            attendance.report_period,
            subject.subject_name_en,
            FIRST(attendance.student_count_diary) AS student_count,
            SUM(attendance.excused_lessons_illness) AS excused_lessons_illness,
            SUM(attendance.excused_lessons_other) AS excused_lessons_other,
            SUM(attendance.unexcused_lessons) AS unexcused_lessons
        FROM attendance
        JOIN school ON attendance.school_code = school.school_code
        JOIN subject ON attendance.subject_code = subject.subject_code
            AND attendance.electronic_diary = subject.electronic_diary
        GROUP BY all
"""
).df()

# %%
df = df[(df["subject_name_en"] == "Mathematics") & (df["student_class"] == 12)]

# %%
# Filter on report period
df = df[df["report_period"].between("2018-09-01", "2024-05-31")]
# Get rid of summer months
df["month"] = df["report_period"].dt.month
df = df[~df["month"].isin([6, 7, 8])]

# Make sure the set of schools is the same across the years
# First, count how many report periods each school has
schools = df.groupby("school_name").agg(
    report_period_count=("report_period", "nunique")
)
# Then, filter on the schools that have data for all 6 school years (9 months each year)
schools = schools[schools["report_period_count"] == 6 * 9]
df = df[df["school_name"].isin(schools.index)]

df["school_year"] = df["report_period"].dt.year - (
    df["report_period"].dt.month <= 5
).astype(int)
df[["report_period", "school_year"]].sample(5)

df["excused_illness_per_student"] = df["excused_lessons_illness"] / df["student_count"]
df["excused_other_per_student"] = df["excused_lessons_other"] / df["student_count"]
df["unexcused_per_student"] = df["unexcused_lessons"] / df["student_count"]
df["total_missed"] = (
    df["excused_lessons_illness"]
    + df["excused_lessons_other"]
    + df["unexcused_lessons"]
)
df["total_missed_per_student"] = df["total_missed"] / df["student_count"]
df["report_period"] = df["report_period"].dt.date

df.sample(5)
# Out:
#                                                school_name  school_code  \
# 1841285  Kelmės rajono Užvenčio Šatrijos Raganos gimnazija    190092914
# 2974260     Jurbarko Antano Giedraičio-Giedriaus gimnazija    290917890
# 4308309                      Pasvalio r. Pumpėnų gimnazija    190615485
# 4228381             Šilutės r. Švėkšnos „Saulės“ gimnazija    290697540
# 2933755                          Palangos senoji gimnazija    190274564
#
#         municipality_name  student_class report_period subject_name_en  \
# 1841285    Kelmės r. sav.             12    2023-02-01     Mathematics
# 2974260  Jurbarko r. sav.             12    2021-01-01     Mathematics
# 4308309  Pasvalio r. sav.             12    2021-10-01     Mathematics
# 4228381   Šilutės r. sav.             12    2023-11-01     Mathematics
# 2933755  Palangos m. sav.             12    2024-03-01     Mathematics
#
#          student_count  excused_lessons_illness  excused_lessons_other  \
# 1841285             15                     13.0                   12.0
# 2974260            125                     13.0                   12.0
# 4308309             21                     12.0                   15.0
# 4228381             29                     44.0                   28.0
# 2933755            118                     80.0                   11.0
#
#          unexcused_lessons  month  school_year  excused_illness_per_student  \
# 1841285                0.0      2         2022                     0.866667
# 2974260              104.0      1         2020                     0.104000
# 4308309                0.0     10         2021                     0.571429
# 4228381                5.0     11         2023                     1.517241
# 2933755              152.0      3         2023                     0.677966
#
#          excused_other_per_student  unexcused_per_student  total_missed  \
# 1841285                   0.800000               0.000000          25.0
# 2974260                   0.096000               0.832000         129.0
# 4308309                   0.714286               0.000000          27.0
# 4228381                   0.965517               0.172414          77.0
# 2933755                   0.093220               1.288136         243.0
#
#          total_missed_per_student
# 1841285                  1.666667
# 2974260                  1.032000
# 4308309                  1.285714
# 4228381                  2.655172
# 2933755                  2.059322

# %% [markdown]
# ## Tasks

# %% [markdown]
# ### Task 1
#
# Show how average `total_missed_per_student` changes across time. The plot should be titled, and axes should be labelled clearly.

# %%
# Answer
plt.figure(figsize=(10, 5))
sns.lineplot(data=df, x="report_period", y="total_missed_per_student")
plt.title("Average Total Missed per Student Over Time")
plt.xlabel("Report Period")
plt.ylabel(None);

# %% [markdown]
# ### Task 2
#
# Show how average `total_missed_per_student` changes across time for these municipalities:
#
# * Vilniaus m. sav.
# * Vilniaus r. sav.
# * Kauno m. sav.
# * Kauno r. sav.
#
# The lines should have no errorbar.

# %%
municipalities = [
    "Vilniaus m. sav.",
    "Vilniaus r. sav.",
    "Kauno m. sav.",
    "Kauno r. sav.",
]

# %%
# Answer
df_municipalities = df[df["municipality_name"].isin(municipalities)]

plt.figure(figsize=(10, 5))
sns.lineplot(
    data=df_municipalities,
    x="report_period",
    y="total_missed_per_student",
    hue="municipality_name",
    errorbar=None
)
plt.title("Average Total Missed per Student Over Time for Vilnius and Kaunas")
plt.xlabel("Report Period")
plt.legend(title="Municipality")

# %% [markdown]
# ### Task 3
#
# There's something going on in the Vilnius region in school year 2023. Only for that municipality and school year, plot `total_missed_per_student` across time *by school*.
#
# The plot should be titled and labelled clearly.

# %%
# Answer
df_2023_vilnius_r = df[
    (df["school_year"] == 2023) & (df["municipality_name"] == "Vilniaus r. sav.")
]

plt.figure(figsize=(10, 5))
sns.lineplot(
    data=df_2023_vilnius_r,
    x="report_period",
    y="total_missed_per_student",
    hue="school_name",
)
plt.title("Total Missed per Student in Vilnius Region in School year 2023")
plt.xlabel("Report Period")
plt.ylabel(None)
plt.legend(title="School")

# %% [markdown]
# ### Task 4
#
# The plot above is not very nice to look at. Let's make it into a table.
#
# Each row of the table should represent one school. Each column should be one report period. Only show data from 2023-09 to 2023-12. Apply conditional formatting on the *rows* of the table. The numbers in the table should be rounded to two significant digits.
#
# Hint - you will have to pivot the table.

# %%
# Answer
df_2023_vilnius_r_9_12 = df_2023_vilnius_r[(df_2023_vilnius_r["month"].between(9, 12))]

pivoted = df_2023_vilnius_r_9_12.pivot(
    index="school_name", columns="report_period", values="total_missed_per_student"
)

pivoted.style.background_gradient(axis=1).format(precision=2)
# Out:
# <style type="text/css">
# #T_724aa_row0_col0, #T_724aa_row1_col1, #T_724aa_row2_col0, #T_724aa_row3_col1, #T_724aa_row4_col0, #T_724aa_row5_col0, #T_724aa_row6_col1, #T_724aa_row7_col3, #T_724aa_row8_col0, #T_724aa_row9_col1, #T_724aa_row10_col0, #T_724aa_row11_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_724aa_row0_col1 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_724aa_row0_col2 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_724aa_row0_col3, #T_724aa_row1_col2, #T_724aa_row2_col2, #T_724aa_row3_col2, #T_724aa_row4_col3, #T_724aa_row5_col3, #T_724aa_row6_col3, #T_724aa_row7_col2, #T_724aa_row8_col2, #T_724aa_row9_col2, #T_724aa_row10_col2, #T_724aa_row11_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_724aa_row1_col0 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_724aa_row1_col3 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_724aa_row2_col1 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_724aa_row2_col3 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_724aa_row3_col0 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_724aa_row3_col3 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_724aa_row4_col1 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_724aa_row4_col2 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_724aa_row5_col1 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_724aa_row5_col2 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_724aa_row6_col0 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_724aa_row6_col2 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_724aa_row7_col0, #T_724aa_row7_col1, #T_724aa_row8_col1 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_724aa_row8_col3 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_724aa_row9_col0 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_724aa_row9_col3 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_724aa_row10_col1 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_724aa_row10_col3 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_724aa_row11_col0 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_724aa_row11_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# </style>
# <table id="T_724aa">
#   <thead>
#     <tr>
#       <th class="index_name level0" >report_period</th>
#       <th id="T_724aa_level0_col0" class="col_heading level0 col0" >2023-09-01</th>
#       <th id="T_724aa_level0_col1" class="col_heading level0 col1" >2023-10-01</th>
#       <th id="T_724aa_level0_col2" class="col_heading level0 col2" >2023-11-01</th>
#       <th id="T_724aa_level0_col3" class="col_heading level0 col3" >2023-12-01</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >school_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_724aa_level0_row0" class="row_heading level0 row0" >Eitminiškių gimnazija</th>
#       <td id="T_724aa_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_724aa_row0_col1" class="data row0 col1" >1.73</td>
#       <td id="T_724aa_row0_col2" class="data row0 col2" >1.36</td>
#       <td id="T_724aa_row0_col3" class="data row0 col3" >2.70</td>
#     </tr>
#     <tr>
#       <th id="T_724aa_level0_row1" class="row_heading level0 row1" >Lavoriškių gimnazija</th>
#       <td id="T_724aa_row1_col0" class="data row1 col0" >6.28</td>
#       <td id="T_724aa_row1_col1" class="data row1 col1" >1.67</td>
#       <td id="T_724aa_row1_col2" class="data row1 col2" >17.47</td>
#       <td id="T_724aa_row1_col3" class="data row1 col3" >6.56</td>
#     </tr>
#     <tr>
#       <th id="T_724aa_level0_row2" class="row_heading level0 row2" >Vilniaus r. Bezdonių Julijaus Slovackio gimnazija</th>
#       <td id="T_724aa_row2_col0" class="data row2 col0" >3.00</td>
#       <td id="T_724aa_row2_col1" class="data row2 col1" >4.45</td>
#       <td id="T_724aa_row2_col2" class="data row2 col2" >7.23</td>
#       <td id="T_724aa_row2_col3" class="data row2 col3" >4.50</td>
#     </tr>
#     <tr>
#       <th id="T_724aa_level0_row3" class="row_heading level0 row3" >Vilniaus r. Kalvelių Stanislavo Moniuškos gimnazija</th>
#       <td id="T_724aa_row3_col0" class="data row3 col0" >5.14</td>
#       <td id="T_724aa_row3_col1" class="data row3 col1" >4.00</td>
#       <td id="T_724aa_row3_col2" class="data row3 col2" >11.19</td>
#       <td id="T_724aa_row3_col3" class="data row3 col3" >5.71</td>
#     </tr>
#     <tr>
#       <th id="T_724aa_level0_row4" class="row_heading level0 row4" >Vilniaus r. Maišiagalos Lietuvos didžiojo kunigaikščio Algirdo gimnazija</th>
#       <td id="T_724aa_row4_col0" class="data row4 col0" >0.95</td>
#       <td id="T_724aa_row4_col1" class="data row4 col1" >1.21</td>
#       <td id="T_724aa_row4_col2" class="data row4 col2" >1.16</td>
#       <td id="T_724aa_row4_col3" class="data row4 col3" >2.00</td>
#     </tr>
#     <tr>
#       <th id="T_724aa_level0_row5" class="row_heading level0 row5" >Vilniaus r. Mickūnų gimnazija</th>
#       <td id="T_724aa_row5_col0" class="data row5 col0" >2.20</td>
#       <td id="T_724aa_row5_col1" class="data row5 col1" >2.72</td>
#       <td id="T_724aa_row5_col2" class="data row5 col2" >3.60</td>
#       <td id="T_724aa_row5_col3" class="data row5 col3" >4.44</td>
#     </tr>
#     <tr>
#       <th id="T_724aa_level0_row6" class="row_heading level0 row6" >Vilniaus r. Nemenčinės Konstanto Parčevskio gimnazija</th>
#       <td id="T_724aa_row6_col0" class="data row6 col0" >5.39</td>
#       <td id="T_724aa_row6_col1" class="data row6 col1" >3.09</td>
#       <td id="T_724aa_row6_col2" class="data row6 col2" >4.94</td>
#       <td id="T_724aa_row6_col3" class="data row6 col3" >7.91</td>
#     </tr>
#     <tr>
#       <th id="T_724aa_level0_row7" class="row_heading level0 row7" >Vilniaus r. Paberžės šv. Stanislavo Kostkos gimnazija</th>
#       <td id="T_724aa_row7_col0" class="data row7 col0" >0.07</td>
#       <td id="T_724aa_row7_col1" class="data row7 col1" >0.07</td>
#       <td id="T_724aa_row7_col2" class="data row7 col2" >0.20</td>
#       <td id="T_724aa_row7_col3" class="data row7 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_724aa_level0_row8" class="row_heading level0 row8" >Vilniaus r. Rudaminos Ferdinando Ruščico gimnazija</th>
#       <td id="T_724aa_row8_col0" class="data row8 col0" >1.27</td>
#       <td id="T_724aa_row8_col1" class="data row8 col1" >2.58</td>
#       <td id="T_724aa_row8_col2" class="data row8 col2" >5.16</td>
#       <td id="T_724aa_row8_col3" class="data row8 col3" >2.35</td>
#     </tr>
#     <tr>
#       <th id="T_724aa_level0_row9" class="row_heading level0 row9" >Vilniaus r. Rudaminos „Ryto“ gimnazija</th>
#       <td id="T_724aa_row9_col0" class="data row9 col0" >3.14</td>
#       <td id="T_724aa_row9_col1" class="data row9 col1" >1.86</td>
#       <td id="T_724aa_row9_col2" class="data row9 col2" >3.68</td>
#       <td id="T_724aa_row9_col3" class="data row9 col3" >2.04</td>
#     </tr>
#     <tr>
#       <th id="T_724aa_level0_row10" class="row_heading level0 row10" >Vilniaus r. Rukainių gimnazija</th>
#       <td id="T_724aa_row10_col0" class="data row10 col0" >1.44</td>
#       <td id="T_724aa_row10_col1" class="data row10 col1" >2.08</td>
#       <td id="T_724aa_row10_col2" class="data row10 col2" >2.64</td>
#       <td id="T_724aa_row10_col3" class="data row10 col3" >1.92</td>
#     </tr>
#     <tr>
#       <th id="T_724aa_level0_row11" class="row_heading level0 row11" >Vilniaus r. Zujūnų gimnazija</th>
#       <td id="T_724aa_row11_col0" class="data row11 col0" >2.57</td>
#       <td id="T_724aa_row11_col1" class="data row11 col1" >2.43</td>
#       <td id="T_724aa_row11_col2" class="data row11 col2" >9.71</td>
#       <td id="T_724aa_row11_col3" class="data row11 col3" >2.07</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Task 5
#
# What's causing a spike in total missed lessons on 2023-11 - unexcused missed lessons, illness, or "other"? Make a visualization that answers this question.

# %%
# Answer
df_2023_vilnius_r_11 = df_2023_vilnius_r[df_2023_vilnius_r["month"] == 11]

df_2023_vilnius_r_11[
    [
        "school_name",
        "excused_illness_per_student",
        "excused_other_per_student",
        "unexcused_per_student",
    ]
].style.background_gradient(axis=1).format(precision=2)
# Out:
# <style type="text/css">
# #T_373a4_row0_col1, #T_373a4_row1_col1, #T_373a4_row2_col1, #T_373a4_row3_col1, #T_373a4_row4_col1, #T_373a4_row5_col1, #T_373a4_row6_col1, #T_373a4_row7_col1, #T_373a4_row8_col1, #T_373a4_row9_col1, #T_373a4_row10_col1, #T_373a4_row11_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_373a4_row0_col2, #T_373a4_row0_col3, #T_373a4_row1_col3, #T_373a4_row2_col3, #T_373a4_row3_col3, #T_373a4_row4_col3, #T_373a4_row5_col3, #T_373a4_row6_col2, #T_373a4_row6_col3, #T_373a4_row7_col2, #T_373a4_row7_col3, #T_373a4_row8_col3, #T_373a4_row9_col3, #T_373a4_row10_col3, #T_373a4_row11_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_373a4_row1_col2 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_373a4_row2_col2 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_373a4_row3_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_373a4_row4_col2 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_373a4_row5_col2 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_373a4_row8_col2 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_373a4_row9_col2 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_373a4_row10_col2 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_373a4_row11_col2 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# </style>
# <table id="T_373a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_373a4_level0_col0" class="col_heading level0 col0" >school_name</th>
#       <th id="T_373a4_level0_col1" class="col_heading level0 col1" >excused_illness_per_student</th>
#       <th id="T_373a4_level0_col2" class="col_heading level0 col2" >excused_other_per_student</th>
#       <th id="T_373a4_level0_col3" class="col_heading level0 col3" >unexcused_per_student</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_373a4_level0_row0" class="row_heading level0 row0" >804437</th>
#       <td id="T_373a4_row0_col0" class="data row0 col0" >Vilniaus r. Bezdonių Julijaus Slovackio gimnazija</td>
#       <td id="T_373a4_row0_col1" class="data row0 col1" >7.23</td>
#       <td id="T_373a4_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_373a4_row0_col3" class="data row0 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_373a4_level0_row1" class="row_heading level0 row1" >1046845</th>
#       <td id="T_373a4_row1_col0" class="data row1 col0" >Vilniaus r. Rudaminos „Ryto“ gimnazija</td>
#       <td id="T_373a4_row1_col1" class="data row1 col1" >3.36</td>
#       <td id="T_373a4_row1_col2" class="data row1 col2" >0.32</td>
#       <td id="T_373a4_row1_col3" class="data row1 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_373a4_level0_row2" class="row_heading level0 row2" >1391700</th>
#       <td id="T_373a4_row2_col0" class="data row2 col0" >Vilniaus r. Paberžės šv. Stanislavo Kostkos gimnazija</td>
#       <td id="T_373a4_row2_col1" class="data row2 col1" >0.13</td>
#       <td id="T_373a4_row2_col2" class="data row2 col2" >0.07</td>
#       <td id="T_373a4_row2_col3" class="data row2 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_373a4_level0_row3" class="row_heading level0 row3" >1682666</th>
#       <td id="T_373a4_row3_col0" class="data row3 col0" >Vilniaus r. Rukainių gimnazija</td>
#       <td id="T_373a4_row3_col1" class="data row3 col1" >2.52</td>
#       <td id="T_373a4_row3_col2" class="data row3 col2" >0.12</td>
#       <td id="T_373a4_row3_col3" class="data row3 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_373a4_level0_row4" class="row_heading level0 row4" >1790398</th>
#       <td id="T_373a4_row4_col0" class="data row4 col0" >Vilniaus r. Nemenčinės Konstanto Parčevskio gimnazija</td>
#       <td id="T_373a4_row4_col1" class="data row4 col1" >2.58</td>
#       <td id="T_373a4_row4_col2" class="data row4 col2" >2.36</td>
#       <td id="T_373a4_row4_col3" class="data row4 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_373a4_level0_row5" class="row_heading level0 row5" >1910012</th>
#       <td id="T_373a4_row5_col0" class="data row5 col0" >Lavoriškių gimnazija</td>
#       <td id="T_373a4_row5_col1" class="data row5 col1" >14.58</td>
#       <td id="T_373a4_row5_col2" class="data row5 col2" >2.89</td>
#       <td id="T_373a4_row5_col3" class="data row5 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_373a4_level0_row6" class="row_heading level0 row6" >1975836</th>
#       <td id="T_373a4_row6_col0" class="data row6 col0" >Eitminiškių gimnazija</td>
#       <td id="T_373a4_row6_col1" class="data row6 col1" >1.36</td>
#       <td id="T_373a4_row6_col2" class="data row6 col2" >0.00</td>
#       <td id="T_373a4_row6_col3" class="data row6 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_373a4_level0_row7" class="row_heading level0 row7" >2182832</th>
#       <td id="T_373a4_row7_col0" class="data row7 col0" >Vilniaus r. Maišiagalos Lietuvos didžiojo kunigaikščio Algirdo gimnazija</td>
#       <td id="T_373a4_row7_col1" class="data row7 col1" >1.16</td>
#       <td id="T_373a4_row7_col2" class="data row7 col2" >0.00</td>
#       <td id="T_373a4_row7_col3" class="data row7 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_373a4_level0_row8" class="row_heading level0 row8" >3419225</th>
#       <td id="T_373a4_row8_col0" class="data row8 col0" >Vilniaus r. Zujūnų gimnazija</td>
#       <td id="T_373a4_row8_col1" class="data row8 col1" >7.79</td>
#       <td id="T_373a4_row8_col2" class="data row8 col2" >1.93</td>
#       <td id="T_373a4_row8_col3" class="data row8 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_373a4_level0_row9" class="row_heading level0 row9" >3488753</th>
#       <td id="T_373a4_row9_col0" class="data row9 col0" >Vilniaus r. Kalvelių Stanislavo Moniuškos gimnazija</td>
#       <td id="T_373a4_row9_col1" class="data row9 col1" >10.10</td>
#       <td id="T_373a4_row9_col2" class="data row9 col2" >1.10</td>
#       <td id="T_373a4_row9_col3" class="data row9 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_373a4_level0_row10" class="row_heading level0 row10" >3909675</th>
#       <td id="T_373a4_row10_col0" class="data row10 col0" >Vilniaus r. Mickūnų gimnazija</td>
#       <td id="T_373a4_row10_col1" class="data row10 col1" >2.84</td>
#       <td id="T_373a4_row10_col2" class="data row10 col2" >0.76</td>
#       <td id="T_373a4_row10_col3" class="data row10 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_373a4_level0_row11" class="row_heading level0 row11" >4869393</th>
#       <td id="T_373a4_row11_col0" class="data row11 col0" >Vilniaus r. Rudaminos Ferdinando Ruščico gimnazija</td>
#       <td id="T_373a4_row11_col1" class="data row11 col1" >4.00</td>
#       <td id="T_373a4_row11_col2" class="data row11 col2" >1.16</td>
#       <td id="T_373a4_row11_col3" class="data row11 col3" >0.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Task 6
#
# For the four municipalities mentioned above and for the report period of 2023-05-01, create a scatter plot with `excused_illness_per_student` on the y axis and `excused_other_per_student` on the x axis. Indicate which municipality the point on the plot belongs to.
#
# The plot should be titled and labelled clearly.

# %%
# Answer
df_municipalities_2023_05 = df[
    (
        (df["school_year"] == 2023) & (df["month"] == 5)
    )
    & df["municipality_name"].isin(municipalities)
]

plt.figure(figsize=(10, 5))
sns.scatterplot(
    data=df_municipalities_2023_05,
    x="excused_other_per_student",
    y="excused_illness_per_student",
    hue="municipality_name",
)
plt.title("Scatter Plot of Excused Illness and Other per Student")
plt.xlabel("Excused Other per Student")
plt.ylabel("Excused Illness per Student")
plt.legend(title="Municipality")
plt.show()

# %% [markdown]
# ### Task 7
#
# Plot the distribution of `total_missed_per_student` on a kdeplot for school year 2020, months September, February and May. Different months should have different curves.
#
# The plot should be titled and labelled clearly.

# %%
# Answer
df_2020 = df[(df["school_year"] == 2020) & (df["month"].isin([9, 2, 5]))]

sns.kdeplot(
    data=df_2020,
    x="excused_illness_per_student",
    hue="report_period",
)
plt.title("KDE Plot of Excused Illness per Student")
plt.xlabel("Excused Illness per Student")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# ### Task 8
#
# So far we've been making single plots. How can we create multiple plots on a single canvas?
#
# Plot the same plot as above, but for both `excused_other_per_student` and `excused_illness_per_student` on separate plots, but on the same canvas.
#
# All plots should be titled and labelled clearly.

# %%
# Hint
fig, axs = plt.subplots(2, 2, figsize=(10, 7))
sns.lineplot(data=df, x="report_period", y="excused_other_per_student", ax=axs[0][0])
# Out:
# <Axes: xlabel='report_period', ylabel='excused_other_per_student'>

# %%
# Answer
fig, axs = plt.subplots(1, 2, figsize=(10, 5), sharey=True)

sns.kdeplot(data=df_2020, x="excused_other_per_student", ax=axs[0], hue="report_period")
axs[0].set_title("Excused Other per Student")
axs[0].set_xlabel(None)

sns.kdeplot(
    data=df_2020, x="excused_illness_per_student", ax=axs[1], hue="report_period"
)
axs[1].set_title("Excused Illness per Student")
axs[1].set_xlabel(None)
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# ### Task 9
#
# Now plot all three metrics on different plots, but still the same canvas. Don't repeat yourself! (use a for loop)
#
# ```
#
# ```

# %%
# Hint
columns = [...]
fig, axs = plt.subplots(1, 3, figsize=(..., ...))
for column, ax in zip(columns, axs):
    pass
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 # Hint
#       2 columns = [...]
# ----> 3 fig, axs = plt.subplots(1, 3, figsize=(..., ...))
#       4 for column, ax in zip(columns, axs):
#       5     pass
#
# File ~/personal/ism/ism-data-science-2026/.venv/lib/python3.12/site-packages/matplotlib/pyplot.py:1776, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1621 def subplots(
#    1622     nrows: int = 1, ncols: int = 1, *,
#    1623     sharex: bool | Literal["none", "all", "row", "col"] = False,
#    (...)   1630     **fig_kw
#    1631 ) -> tuple[Figure, Any]:
#    1632     """
#    1633     Create a figure and a set of subplots.
#    1634
#    (...)   1774
#    1775     """
# -> 1776     fig = figure(**fig_kw)
#    1777     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1778                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1779                        gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1780                        width_ratios=width_ratios)
#    1781     return fig, axs
#
# File ~/personal/ism/ism-data-science-2026/.venv/lib/python3.12/site-packages/matplotlib/pyplot.py:1041, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#    1031 if len(allnums) == max_open_warning >= 1:
#    1032     _api.warn_external(
#    1033         f"More than {max_open_warning} figures have been opened. "
#    1034         f"Figures created through the pyplot interface "
#    (...)   1038         f"Consider using `matplotlib.pyplot.close()`.",
#    1039         RuntimeWarning)
# -> 1041 manager = new_figure_manager(
#    1042     num, figsize=figsize, dpi=dpi,
#    1043     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#    1044     FigureClass=FigureClass, **kwargs)
#    1045 fig = manager.canvas.figure
#    1046 if fig_label:
#
# File ~/personal/ism/ism-data-science-2026/.venv/lib/python3.12/site-packages/matplotlib/pyplot.py:551, in new_figure_manager(*args, **kwargs)
#     549 """Create a new figure manager instance."""
#     550 _warn_if_gui_out_of_main_thread()
# --> 551 return _get_backend_mod().new_figure_manager(*args, **kwargs)
#
# File ~/personal/ism/ism-data-science-2026/.venv/lib/python3.12/site-packages/matplotlib_inline/backend_inline.py:26, in new_figure_manager(num, FigureClass, *args, **kwargs)
#      20 def new_figure_manager(num, *args, FigureClass=Figure, **kwargs):
#      21     """
#      22     Return a new figure manager for a new figure instance.
#      23
#      24     This function is part of the API expected by Matplotlib backends.
#      25     """
# ---> 26     return new_figure_manager_given_figure(num, FigureClass(*args, **kwargs))
#
# File ~/personal/ism/ism-data-science-2026/.venv/lib/python3.12/site-packages/matplotlib/figure.py:2623, in Figure.__init__(self, figsize, dpi, facecolor, edgecolor, linewidth, frameon, subplotpars, tight_layout, constrained_layout, layout, **kwargs)
#    2620 if frameon is None:
#    2621     frameon = mpl.rcParams['figure.frameon']
# -> 2623 if not np.isfinite(figsize).all() or (np.array(figsize) < 0).any():
#    2624     raise ValueError('figure size must be positive finite not '
#    2625                      f'{figsize}')
#    2626 self.bbox_inches = Bbox.from_bounds(0, 0, *figsize)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
# Answer
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
columns = [
    "excused_other_per_student",
    "excused_illness_per_student",
    "unexcused_per_student",
]

for column, ax in zip(columns, axs):
    sns.kdeplot(data=df_2020, x=column, ax=ax, hue="month")
    ax.set_title(column)
    ax.set_xlabel(None)

# %% [markdown]
# ### Task 10
#
# One last table - show the number of schools, and then average, median and 90th percentile of `total_missed_per_student` by *municipality*, for the whole period (you don't need to apply any filters).
#
# Display top 20 schools by school count. Apply conditional formatting on the table such that outliers in each column stand out. Do not apply conditional formatting on the school count column.

# %%
# hint - do this in the aggregation step
("total_missed_per_student", lambda x: x.quantile(0.8))
# Out:
# ('total_missed_per_student', <function __main__.<lambda>(x)>)

# %%
# Step 1
# Aggregate by municipality
df_agg = df.groupby("municipality_name").agg(
    school_count=("school_name", "nunique"),
    mean_missed_per_student=("total_missed_per_student", "mean"),
    median_missed_per_student=("total_missed_per_student", "median"),
    perc_90_missed_per_student=("total_missed_per_student", lambda x: x.quantile(0.9)),
)
df_agg
# Out:
#                      school_count  mean_missed_per_student  \
# municipality_name
# Akmenės r. sav.                 4                 1.362629
# Alytaus m. sav.                 4                 1.843795
# Alytaus r. sav.                 4                 1.440894
# Anykščių r. sav.                1                 1.854703
# Birštono sav.                   1                 1.991240
# Biržų r. sav.                   2                 2.181808
# Druskininkų sav.                1                 1.769249
# Elektrėnų sav.                  3                 1.632446
# Ignalinos r. sav.               3                 1.749105
# Joniškio r. sav.                2                 1.693708
# Jurbarko r. sav.                2                 1.947695
# Kaišiadorių r. sav.             3                 1.695439
# Kauno m. sav.                  16                 1.423337
# Kauno r. sav.                   7                 1.565639
# Kazlų Rūdos sav.                2                 1.425386
# Kelmės r. sav.                  2                 1.514339
# Klaipėdos m. sav.              13                 1.501185
# Klaipėdos r. sav.               2                 2.053805
# Kretingos r. sav.               1                 2.026335
# Kupiškio r. sav.                1                 1.096310
# Kėdainių r. sav.                3                 1.221981
# Lazdijų r. sav.                 2                 1.202668
# Marijampolės sav.               5                 1.798520
# Mažeikių r. sav.                3                 1.432401
# Molėtų r. sav.                  1                 1.856532
# Pakruojo r. sav.                1                 1.383340
# Palangos m. sav.                1                 1.735245
# Panevėžio m. sav.               4                 1.342333
# Panevėžio r. sav.               2                 1.343564
# Pasvalio r. sav.                4                 1.693021
# Plungės r. sav.                 3                 1.998239
# Prienų r. sav.                  4                 1.722089
# Radviliškio r. sav.             4                 1.692112
# Raseinių r. sav.                2                 1.528455
# Rietavo sav.                    1                 1.890793
# Rokiškio r. sav.                2                 1.728172
# Tauragės r. sav.                4                 1.109454
# Telšių r. sav.                  2                 1.544244
# Trakų r. sav.                   3                 1.632372
# Ukmergės r. sav.                3                 1.448468
# Utenos r. sav.                  3                 1.818039
# Varėnos r. sav.                 3                 1.440237
# Vilkaviškio r. sav.             3                 1.716864
# Vilniaus m. sav.               27                 1.863925
# Vilniaus r. sav.               12                 1.421369
# Visagino sav.                   2                 1.754901
# Zarasų r. sav.                  2                 2.073747
# Šakių r. sav.                   2                 1.822635
# Šalčininkų r. sav.              8                 1.358287
# Šiaulių m. sav.                 7                 1.557644
# Šiaulių r. sav.                 1                 1.246497
# Šilalės r. sav.                 5                 1.671297
# Šilutės r. sav.                 3                 2.073702
# Širvintų r. sav.                3                 1.553681
# Švenčionių r. sav.              1                 2.203208
#
#                      median_missed_per_student  perc_90_missed_per_student
# municipality_name
# Akmenės r. sav.                       1.267949                    2.937976
# Alytaus m. sav.                       1.947565                    3.120192
# Alytaus r. sav.                       1.204167                    3.258242
# Anykščių r. sav.                      1.913223                    2.726483
# Birštono sav.                         1.851326                    3.199167
# Biržų r. sav.                         2.254630                    3.500488
# Druskininkų sav.                      1.719161                    2.511033
# Elektrėnų sav.                        1.574501                    3.034155
# Ignalinos r. sav.                     1.710000                    3.285950
# Joniškio r. sav.                      1.678571                    3.098930
# Jurbarko r. sav.                      1.958716                    2.966667
# Kaišiadorių r. sav.                   1.609127                    3.104537
# Kauno m. sav.                         1.234432                    2.743793
# Kauno r. sav.                         1.496481                    2.788515
# Kazlų Rūdos sav.                      1.082483                    3.161789
# Kelmės r. sav.                        1.441610                    2.288462
# Klaipėdos m. sav.                     1.387793                    2.833079
# Klaipėdos r. sav.                     2.051724                    3.356518
# Kretingos r. sav.                     2.083812                    2.872940
# Kupiškio r. sav.                      1.027778                    2.038889
# Kėdainių r. sav.                      1.267752                    1.953177
# Lazdijų r. sav.                       1.198718                    2.154167
# Marijampolės sav.                     1.489295                    3.933750
# Mažeikių r. sav.                      1.415123                    2.257123
# Molėtų r. sav.                        1.795131                    2.829175
# Pakruojo r. sav.                      1.455894                    1.948140
# Palangos m. sav.                      1.715331                    2.369570
# Panevėžio m. sav.                     1.213881                    2.286296
# Panevėžio r. sav.                     1.418449                    2.371622
# Pasvalio r. sav.                      1.255081                    3.559130
# Plungės r. sav.                       1.835060                    3.465455
# Prienų r. sav.                        1.462567                    3.918045
# Radviliškio r. sav.                   1.392308                    3.255747
# Raseinių r. sav.                      1.461842                    2.733391
# Rietavo sav.                          1.967134                    3.012361
# Rokiškio r. sav.                      1.627016                    3.013636
# Tauragės r. sav.                      1.250000                    2.232057
# Telšių r. sav.                        1.250000                    3.463736
# Trakų r. sav.                         1.535714                    2.990000
# Ukmergės r. sav.                      1.371047                    2.712594
# Utenos r. sav.                        1.799662                    2.884211
# Varėnos r. sav.                       1.000000                    3.466316
# Vilkaviškio r. sav.                   1.443803                    3.226923
# Vilniaus m. sav.                      1.744668                    3.286349
# Vilniaus r. sav.                      1.084118                    2.949573
# Visagino sav.                         1.570833                    3.351434
# Zarasų r. sav.                        1.941176                    3.673214
# Šakių r. sav.                         1.513324                    3.405895
# Šalčininkų r. sav.                    1.000000                    2.956618
# Šiaulių m. sav.                       1.461211                    2.853671
# Šiaulių r. sav.                       1.083333                    2.550000
# Šilalės r. sav.                       1.763834                    3.300000
# Šilutės r. sav.                       1.842647                    3.795000
# Širvintų r. sav.                      1.438750                    3.055967
# Švenčionių r. sav.                    2.299355                    3.595946

# %%
# Step 2
# Display the table
df_agg_sorted = df_agg.sort_values(by="school_count", ascending=False).head(20)

df_agg_sorted.style.background_gradient(
    subset=[
        "mean_missed_per_student",
        "median_missed_per_student",
        "perc_90_missed_per_student",
    ]
)
# Out:
# <style type="text/css">
# #T_3e31a_row0_col1 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_3e31a_row0_col2 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_3e31a_row0_col3 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_3e31a_row1_col1, #T_3e31a_row6_col3 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_3e31a_row1_col2 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_3e31a_row1_col3 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_3e31a_row2_col1, #T_3e31a_row2_col2 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_3e31a_row2_col3 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_3e31a_row3_col1 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_3e31a_row3_col2 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_3e31a_row3_col3 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_3e31a_row4_col1 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_3e31a_row4_col2, #T_3e31a_row10_col1, #T_3e31a_row10_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_3e31a_row4_col3 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_3e31a_row5_col1, #T_3e31a_row18_col2 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_3e31a_row5_col2, #T_3e31a_row12_col2 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_3e31a_row5_col3 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_3e31a_row6_col1 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_3e31a_row6_col2 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_3e31a_row7_col1 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_3e31a_row7_col2 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_3e31a_row7_col3 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_3e31a_row8_col1 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_3e31a_row8_col2 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_3e31a_row8_col3, #T_3e31a_row14_col2, #T_3e31a_row19_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_3e31a_row9_col1, #T_3e31a_row10_col2 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_3e31a_row9_col2 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_3e31a_row9_col3 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_3e31a_row11_col1, #T_3e31a_row11_col3, #T_3e31a_row13_col1, #T_3e31a_row16_col3 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_3e31a_row11_col2 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_3e31a_row12_col1 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_3e31a_row12_col3 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_3e31a_row13_col2 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_3e31a_row13_col3 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_3e31a_row14_col1 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_3e31a_row14_col3 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_3e31a_row15_col1 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_3e31a_row15_col2 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_3e31a_row15_col3 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_3e31a_row16_col1 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_3e31a_row16_col2 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_3e31a_row17_col1 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_3e31a_row17_col2 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_3e31a_row17_col3 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_3e31a_row18_col1 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_3e31a_row18_col3 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_3e31a_row19_col2 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_3e31a_row19_col3 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3e31a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e31a_level0_col0" class="col_heading level0 col0" >school_count</th>
#       <th id="T_3e31a_level0_col1" class="col_heading level0 col1" >mean_missed_per_student</th>
#       <th id="T_3e31a_level0_col2" class="col_heading level0 col2" >median_missed_per_student</th>
#       <th id="T_3e31a_level0_col3" class="col_heading level0 col3" >perc_90_missed_per_student</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >municipality_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e31a_level0_row0" class="row_heading level0 row0" >Vilniaus m. sav.</th>
#       <td id="T_3e31a_row0_col0" class="data row0 col0" >27</td>
#       <td id="T_3e31a_row0_col1" class="data row0 col1" >1.863925</td>
#       <td id="T_3e31a_row0_col2" class="data row0 col2" >1.744668</td>
#       <td id="T_3e31a_row0_col3" class="data row0 col3" >3.286349</td>
#     </tr>
#     <tr>
#       <th id="T_3e31a_level0_row1" class="row_heading level0 row1" >Kauno m. sav.</th>
#       <td id="T_3e31a_row1_col0" class="data row1 col0" >16</td>
#       <td id="T_3e31a_row1_col1" class="data row1 col1" >1.423337</td>
#       <td id="T_3e31a_row1_col2" class="data row1 col2" >1.234432</td>
#       <td id="T_3e31a_row1_col3" class="data row1 col3" >2.743793</td>
#     </tr>
#     <tr>
#       <th id="T_3e31a_level0_row2" class="row_heading level0 row2" >Klaipėdos m. sav.</th>
#       <td id="T_3e31a_row2_col0" class="data row2 col0" >13</td>
#       <td id="T_3e31a_row2_col1" class="data row2 col1" >1.501185</td>
#       <td id="T_3e31a_row2_col2" class="data row2 col2" >1.387793</td>
#       <td id="T_3e31a_row2_col3" class="data row2 col3" >2.833079</td>
#     </tr>
#     <tr>
#       <th id="T_3e31a_level0_row3" class="row_heading level0 row3" >Vilniaus r. sav.</th>
#       <td id="T_3e31a_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_3e31a_row3_col1" class="data row3 col1" >1.421369</td>
#       <td id="T_3e31a_row3_col2" class="data row3 col2" >1.084118</td>
#       <td id="T_3e31a_row3_col3" class="data row3 col3" >2.949573</td>
#     </tr>
#     <tr>
#       <th id="T_3e31a_level0_row4" class="row_heading level0 row4" >Šalčininkų r. sav.</th>
#       <td id="T_3e31a_row4_col0" class="data row4 col0" >8</td>
#       <td id="T_3e31a_row4_col1" class="data row4 col1" >1.358287</td>
#       <td id="T_3e31a_row4_col2" class="data row4 col2" >1.000000</td>
#       <td id="T_3e31a_row4_col3" class="data row4 col3" >2.956618</td>
#     </tr>
#     <tr>
#       <th id="T_3e31a_level0_row5" class="row_heading level0 row5" >Šiaulių m. sav.</th>
#       <td id="T_3e31a_row5_col0" class="data row5 col0" >7</td>
#       <td id="T_3e31a_row5_col1" class="data row5 col1" >1.557644</td>
#       <td id="T_3e31a_row5_col2" class="data row5 col2" >1.461211</td>
#       <td id="T_3e31a_row5_col3" class="data row5 col3" >2.853671</td>
#     </tr>
#     <tr>
#       <th id="T_3e31a_level0_row6" class="row_heading level0 row6" >Kauno r. sav.</th>
#       <td id="T_3e31a_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_3e31a_row6_col1" class="data row6 col1" >1.565639</td>
#       <td id="T_3e31a_row6_col2" class="data row6 col2" >1.496481</td>
#       <td id="T_3e31a_row6_col3" class="data row6 col3" >2.788515</td>
#     </tr>
#     <tr>
#       <th id="T_3e31a_level0_row7" class="row_heading level0 row7" >Šilalės r. sav.</th>
#       <td id="T_3e31a_row7_col0" class="data row7 col0" >5</td>
#       <td id="T_3e31a_row7_col1" class="data row7 col1" >1.671297</td>
#       <td id="T_3e31a_row7_col2" class="data row7 col2" >1.763834</td>
#       <td id="T_3e31a_row7_col3" class="data row7 col3" >3.300000</td>
#     </tr>
#     <tr>
#       <th id="T_3e31a_level0_row8" class="row_heading level0 row8" >Marijampolės sav.</th>
#       <td id="T_3e31a_row8_col0" class="data row8 col0" >5</td>
#       <td id="T_3e31a_row8_col1" class="data row8 col1" >1.798520</td>
#       <td id="T_3e31a_row8_col2" class="data row8 col2" >1.489295</td>
#       <td id="T_3e31a_row8_col3" class="data row8 col3" >3.933750</td>
#     </tr>
#     <tr>
#       <th id="T_3e31a_level0_row9" class="row_heading level0 row9" >Akmenės r. sav.</th>
#       <td id="T_3e31a
