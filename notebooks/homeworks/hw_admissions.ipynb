# %% [markdown]
# # Homework 1 - EDA on Admissions Dataset
#
# Name Surname
#
# ## Key Findings

# %%
import pandas as pd
import duckdb
import seaborn as sns


db_path = "data.duckdb"
schema = "data.admissions"

conn = duckdb.connect()
conn.execute(f"ATTACH '{db_path}' AS data (READ_ONLY)")
conn.execute(f"USE {schema}");

# %%
conn.sql("select * from applications order by random() limit 5 ")
# Out:
# ┌─────────────────┬─────────────────┬─────────────────────┬───────────────────────┬────────────────────┬──────────────────┬────────────────┬─────────────────┬─────────────────┬────────────────────┬───────────┬─────────────────────────────┬─────────┬─────────────────┬─────────┐
# │ application_id  │    person_id    │      choice_at      │    admission_stage    │ admission_stage_en │ stage_start_date │ stage_end_date │ priority_number │   program_id    │    financing_en    │ financing │ participated_in_competition │ invited │ invitation_date │ signed  │
# │     varchar     │     varchar     │      timestamp      │        varchar        │      varchar       │       date       │      date      │      int64      │     varchar     │      varchar       │  varchar  │           boolean           │ boolean │      date       │ boolean │
# ├─────────────────┼─────────────────┼─────────────────────┼───────────────────────┼────────────────────┼──────────────────┼────────────────┼─────────────────┼─────────────────┼────────────────────┼───────────┼─────────────────────────────┼─────────┼─────────────────┼─────────┤
# │ bd5af7583d186cd │ f7ad9b9812335e6 │ 2024-06-15 14:28:11 │ Pagrindinis priėmimas │ Main admission     │ 2024-06-01       │ 2024-08-02     │               4 │ b536d11f54ad0a0 │ State financed     │ VF        │ true                        │ false   │ NULL            │ false   │
# │ f9ce19711eb4fcc │ 20087cdfd86f149 │ 2024-07-21 22:25:59 │ Pagrindinis priėmimas │ Main admission     │ 2024-06-01       │ 2024-08-02     │               8 │ 71e3d6abf395864 │ State financed     │ VF        │ true                        │ true    │ 2024-07-31      │ true    │
# │ a8bfde77081857f │ e8c45644a7474aa │ 2024-06-20 21:38:26 │ Pagrindinis priėmimas │ Main admission     │ 2024-06-01       │ 2024-08-02     │               5 │ 8c86311b805244b │ State financed     │ VF        │ false                       │ false   │ NULL            │ false   │
# │ d0404b1ffdd51c2 │ 522eb478377d536 │ 2025-07-09 18:48:54 │ Pagrindinis priėmimas │ Main admission     │ 2025-06-01       │ 2025-08-14     │               3 │ 53ac4b4874bbd38 │ State financed     │ VF        │ true                        │ true    │ 2025-08-10      │ true    │
# │ 26d904f297e2a3f │ 2e28e57b7098225 │ 2024-07-16 08:10:00 │ Pagrindinis priėmimas │ Main admission     │ 2024-06-01       │ 2024-08-02     │               2 │ 6222ae242932cdc │ Not state financed │ VNF       │ true                        │ false   │ NULL            │ false   │
# └─────────────────┴─────────────────┴─────────────────────┴───────────────────────┴────────────────────┴──────────────────┴────────────────┴─────────────────┴─────────────────┴────────────────────┴───────────┴─────────────────────────────┴─────────┴─────────────────┴─────────┘

# %%
conn.sql("select * from profiles order by random() limit 5")
# Out:
# ┌─────────────────┬───────────────────────┬────────────┬─────────┬────────────────────────────┬─────────────────────────────────────────────────────────────┬─────────────────────────────┬────────────────────────┬────────────────────────┬────────────────┬───────────────────┐
# │    person_id    │ is_possibly_foreigner │ birth_year │ gender  │ education_institution_code │                    education_institution                    │ education_municipality_code │ education_municipality │ residence_municipality │ residence_type │ residence_type_en │
# │     varchar     │        boolean        │    date    │ varchar │           int64            │                           varchar                           │            int64            │        varchar         │        varchar         │    varchar     │      varchar      │
# ├─────────────────┼───────────────────────┼────────────┼─────────┼────────────────────────────┼─────────────────────────────────────────────────────────────┼─────────────────────────────┼────────────────────────┼────────────────────────┼────────────────┼───────────────────┤
# │ 94cbafa2b1dcb35 │ false                 │ 1994-01-01 │ moteris │                  190807514 │ Viešoji įstaiga Telšių regioninis profesinio mokymo centras │                          78 │ Telšių r. sav.         │ Telšių r. sav.         │ miestas        │ City              │
# │ 71e32e216908858 │ false                 │ 2005-01-01 │ vyras   │                  190531375 │ Šiaulių Didždvario gimnazija                                │                          29 │ Šiaulių m. sav.        │ Šiaulių m. sav.        │ miestas        │ City              │
# │ 4fb69ab669d8faf │ false                 │ 2005-01-01 │ vyras   │                  190444479 │ Klaipėdos „Vėtrungės“ gimnazija                             │                          21 │ Klaipėdos m. sav.      │ Klaipėdos m. sav.      │ miestas        │ City              │
# │ d713dd8eb7a848c │ false                 │ 2000-01-01 │ vyras   │                  195472087 │ Ignalinos Česlovo Kudabos gimnazija                         │                          45 │ Ignalinos r. sav.      │ Ignalinos r. sav.      │ miestas        │ City              │
# │ 0a78a94955356a2 │ false                 │ 1991-01-01 │ moteris │                  191789019 │ Gargždų „Kranto“ progimnazija                               │                          55 │ Klaipėdos r. sav.      │ Klaipėdos r. sav.      │ kaimas         │ Village           │
# └─────────────────┴───────────────────────┴────────────┴─────────┴────────────────────────────┴─────────────────────────────────────────────────────────────┴─────────────────────────────┴────────────────────────┴────────────────────────┴────────────────┴───────────────────┘

# %%
conn.sql("select * from programs order by random() limit 5")
# Out:
# ┌─────────────────┬──────────────┬──────────────┬────────────────────────────────────┬─────────────────────────────────────┬──────────────────┬─────────────────┬───────────────────────────────────┬─────────────┬─────────────────────┬───────────────────┬──────────────────────────────┐
# │   program_id    │ program_year │ program_code │            program_name            │           program_name_en           │ institution_code │ code_validation │      educational_institution      │ county_code │       county        │ municipality_code │         municipality         │
# │     varchar     │     date     │   varchar    │              varchar               │               varchar               │      int64       │     varchar     │              varchar              │    int64    │       varchar       │       int64       │           varchar            │
# ├─────────────────┼──────────────┼──────────────┼────────────────────────────────────┼─────────────────────────────────────┼──────────────────┼─────────────────┼───────────────────────────────────┼─────────────┼─────────────────────┼───────────────────┼──────────────────────────────┤
# │ 7a4c9f9f692cb8f │ 2024-01-01   │ 6121EX019    │ Cheminė technologija ir inžinerija │ Chemical Technology and Engineering │        111950581 │ Tinkamas        │ Kauno technologijos universitetas │           2 │ Kauno apskritis     │                19 │ Kauno miesto savivaldybė     │
# │ 3f16681fc1a0fee │ 2024-01-01   │ 6531KX005    │ Teisė                              │ Law                                 │        111968437 │ Tinkamas        │ Panevėžio kolegija                │           5 │ Panevėžio apskritis │                27 │ Panevėžio miesto savivaldybė │
# │ dd778d22b18336a │ 2024-01-01   │ 6121EX014    │ Transporto elektronika             │ Transporto elektronika              │        111950581 │ Tinkamas        │ Kauno technologijos universitetas │           2 │ Kauno apskritis     │                19 │ Kauno miesto savivaldybė     │
# │ 614bf3276752f39 │ 2024-01-01   │ 6121CX009    │ Geografija                         │ Geography                           │        211950810 │ Tinkamas        │ Vilniaus universitetas            │          10 │ Vilniaus apskritis  │                13 │ Vilniaus miesto savivaldybė  │
# │ f4bd24919bb295c │ 2024-01-01   │ 6121KX010    │ Teisė ir valstybės sienos apsauga  │ Teisė ir valstybės sienos apsauga   │        111951726 │ Tinkamas        │ Mykolo Romerio universitetas      │           2 │ Kauno apskritis     │                19 │ Kauno miesto savivaldybė     │
# └─────────────────┴──────────────┴──────────────┴────────────────────────────────────┴─────────────────────────────────────┴──────────────────┴─────────────────┴───────────────────────────────────┴─────────────┴─────────────────────┴───────────────────┴──────────────────────────────┘
