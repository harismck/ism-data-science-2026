# %% [markdown]
# # Cleaning and analysis of the attendance dataset
#
#
#
# In the first seminar we will use the school attendance dataset. You can find the documentation for this dataset [here](https://github.com/harismck/ism-data-science-2026/blob/main/docs/attendance.md).

# %%
import duckdb

db_path = "data.duckdb"
schema = "data.attendance"

conn = duckdb.connect()
conn.execute(f"ATTACH '{db_path}' AS data (READ_ONLY)")
conn.execute(f"USE {schema}");
